# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# Chatbot Tutorial
# ================
#
# **Author:** [Matthew Inkawhich](https://github.com/MatthewInkawhich)

# %% [markdown]
# In this tutorial, we explore a fun and interesting use-case of recurrent
# sequence-to-sequence models. We will train a simple chatbot using movie
# scripts from the [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html).
#
# Conversational models are a hot topic in artificial intelligence
# research. Chatbots can be found in a variety of settings, including
# customer service applications and online helpdesks. These bots are often
# powered by retrieval-based models, which output predefined responses to
# questions of certain forms. In a highly restricted domain like a
# company's IT helpdesk, these models may be sufficient, however, they are
# not robust enough for more general use-cases. Teaching a machine to
# carry out a meaningful conversation with a human in multiple domains is
# a research question that is far from solved. Recently, the deep learning
# boom has allowed for powerful generative models like Google's [Neural
# Conversational Model](https://arxiv.org/abs/1506.05869), which marks a
# large step towards multi-domain generative conversational models. In
# this tutorial, we will implement this kind of model in PyTorch.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/bot.png){.align-center}
#
# ``` {.python}
# > hello?
# Bot: hello .
# > where am I?
# Bot: you re in a hospital .
# > who are you?
# Bot: i m a lawyer .
# > how are you doing?
# Bot: i m fine .
# > are you my friend?
# Bot: no .
# > you're under arrest
# Bot: i m trying to help you !
# > i'm just kidding
# Bot: i m sorry .
# > where are you from?
# Bot: san francisco .
# > it's time for me to leave
# Bot: i know .
# > goodbye
# Bot: goodbye .
# ```
#
# **Tutorial Highlights**
#
# -   Handle loading and preprocessing of [Cornell Movie-Dialogs
#     Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)
#     dataset
# -   Implement a sequence-to-sequence model with [Luong attention
#     mechanism(s)](https://arxiv.org/abs/1508.04025)
# -   Jointly train encoder and decoder models using mini-batches
# -   Implement greedy-search decoding module
# -   Interact with trained chatbot
#
# **Acknowledgments**
#
# This tutorial borrows code from the following sources:
#
# 1)  Yuan-Kuei Wu's pytorch-chatbot implementation:
#     <https://github.com/ywk991112/pytorch-chatbot>
# 2)  Sean Robertson's practical-pytorch seq2seq-translation example:
#     <https://github.com/spro/practical-pytorch/tree/master/seq2seq-translation>
# 3)  FloydHub Cornell Movie Corpus preprocessing code:
#     <https://github.com/floydhub/textutil-preprocess-cornell-movie-corpus>

# %% [markdown]
# Preparations
# ============
#
# To get started,
# [download](https://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip)
# the Movie-Dialogs Corpus zip file.

# %%
# and put in a ``data/`` directory under the current directory.
#
# After that, let’s import some necessities.
#

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json


# If the current `accelerator <https://pytorch.org/docs/stable/torch.html#accelerators>`__ is available,
# we will use it. Otherwise, we use the CPU.
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# Load & Preprocess Data
# ======================
#
# The next step is to reformat our data file and load the data into
# structures that we can work with.
#
# The [Cornell Movie-Dialogs
# Corpus](https://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html)
# is a rich dataset of movie character dialog:
#
# -   220,579 conversational exchanges between 10,292 pairs of movie
#     characters
# -   9,035 characters from 617 movies
# -   304,713 total utterances
#
# This dataset is large and diverse, and there is a great variation of
# language formality, time periods, sentiment, etc. Our hope is that this
# diversity makes our model robust to many forms of inputs and queries.
#
# First, we'll take a look at some lines of our datafile to see the
# original format.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
corpus_name = "movie-corpus"
corpus = os.path.join("/content/drive/MyDrive/chatbot tutorial", corpus_name)

def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

printLines(os.path.join(corpus, "utterances.jsonl"))
# Out:
# b'{"id": "L1045", "conversation_id": "L1044", "text": "They do not!", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "not", "tag": "RB", "dep": "neg", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L1044", "timestamp": null, "vectors": []}\n'
# b'{"id": "L1044", "conversation_id": "L1044", "text": "They do to!", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "They", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "to", "tag": "TO", "dep": "dobj", "up": 1, "dn": []}, {"tok": "!", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L985", "conversation_id": "L984", "text": "I hope so.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "hope", "tag": "VBP", "dep": "ROOT", "dn": [0, 2, 3]}, {"tok": "so", "tag": "RB", "dep": "advmod", "up": 1, "dn": []}, {"tok": ".", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": "L984", "timestamp": null, "vectors": []}\n'
# b'{"id": "L984", "conversation_id": "L984", "text": "She okay?", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 1, "toks": [{"tok": "She", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "okay", "tag": "RB", "dep": "ROOT", "dn": [0, 2]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L925", "conversation_id": "L924", "text": "Let\'s go.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Let", "tag": "VB", "dep": "ROOT", "dn": [2, 3]}, {"tok": "\'s", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "go", "tag": "VB", "dep": "ccomp", "up": 0, "dn": [1]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L924", "timestamp": null, "vectors": []}\n'
# b'{"id": "L924", "conversation_id": "L924", "text": "Wow", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Wow", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L872", "conversation_id": "L870", "text": "Okay -- you\'re gonna need to learn how to lie.", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 4, "toks": [{"tok": "Okay", "tag": "UH", "dep": "intj", "up": 4, "dn": []}, {"tok": "--", "tag": ":", "dep": "punct", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "\'re", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "gon", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 2, 3, 6, 12]}, {"tok": "na", "tag": "TO", "dep": "aux", "up": 6, "dn": []}, {"tok": "need", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 8]}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 8, "dn": []}, {"tok": "learn", "tag": "VB", "dep": "xcomp", "up": 6, "dn": [7, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 11, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 11, "dn": []}, {"tok": "lie", "tag": "VB", "dep": "xcomp", "up": 8, "dn": [9, 10]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": "L871", "timestamp": null, "vectors": []}\n'
# b'{"id": "L871", "conversation_id": "L870", "text": "No", "speaker": "u2", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "No", "tag": "UH", "dep": "ROOT", "dn": []}]}]}, "reply-to": "L870", "timestamp": null, "vectors": []}\n'
# b'{"id": "L870", "conversation_id": "L870", "text": "I\'m kidding.  You know how sometimes you just become this \\"persona\\"?  And you don\'t know how to quit?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 2, "toks": [{"tok": "I", "tag": "PRP", "dep": "nsubj", "up": 2, "dn": []}, {"tok": "\'m", "tag": "VBP", "dep": "aux", "up": 2, "dn": []}, {"tok": "kidding", "tag": "VBG", "dep": "ROOT", "dn": [0, 1, 3]}, {"tok": ".", "tag": ".", "dep": "punct", "up": 2, "dn": [4]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 3, "dn": []}]}, {"rt": 1, "toks": [{"tok": "You", "tag": "PRP", "dep": "nsubj", "up": 1, "dn": []}, {"tok": "know", "tag": "VBP", "dep": "ROOT", "dn": [0, 6, 11]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 3, "dn": []}, {"tok": "sometimes", "tag": "RB", "dep": "advmod", "up": 6, "dn": [2]}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 6, "dn": []}, {"tok": "just", "tag": "RB", "dep": "advmod", "up": 6, "dn": []}, {"tok": "become", "tag": "VBP", "dep": "ccomp", "up": 1, "dn": [3, 4, 5, 9]}, {"tok": "this", "tag": "DT", "dep": "det", "up": 9, "dn": []}, {"tok": "\\"", "tag": "``", "dep": "punct", "up": 9, "dn": []}, {"tok": "persona", "tag": "NN", "dep": "attr", "up": 6, "dn": [7, 8, 10]}, {"tok": "\\"", "tag": "\'\'", "dep": "punct", "up": 9, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 1, "dn": [12]}, {"tok": " ", "tag": "_SP", "dep": "", "up": 11, "dn": []}]}, {"rt": 4, "toks": [{"tok": "And", "tag": "CC", "dep": "cc", "up": 4, "dn": []}, {"tok": "you", "tag": "PRP", "dep": "nsubj", "up": 4, "dn": []}, {"tok": "do", "tag": "VBP", "dep": "aux", "up": 4, "dn": []}, {"tok": "n\'t", "tag": "RB", "dep": "neg", "up": 4, "dn": []}, {"tok": "know", "tag": "VB", "dep": "ROOT", "dn": [0, 1, 2, 3, 7, 8]}, {"tok": "how", "tag": "WRB", "dep": "advmod", "up": 7, "dn": []}, {"tok": "to", "tag": "TO", "dep": "aux", "up": 7, "dn": []}, {"tok": "quit", "tag": "VB", "dep": "xcomp", "up": 4, "dn": [5, 6]}, {"tok": "?", "tag": ".", "dep": "punct", "up": 4, "dn": []}]}]}, "reply-to": null, "timestamp": null, "vectors": []}\n'
# b'{"id": "L869", "conversation_id": "L866", "text": "Like my fear of wearing pastels?", "speaker": "u0", "meta": {"movie_id": "m0", "parsed": [{"rt": 0, "toks": [{"tok": "Like", "tag": "IN", "dep": "ROOT", "dn": [2, 6]}, {"tok": "my", "tag": "PRP$", "dep": "poss", "up": 2, "dn": []}, {"tok": "fear", "tag": "NN", "dep": "pobj", "up": 0, "dn": [1, 3]}, {"tok": "of", "tag": "IN", "dep": "prep", "up": 2, "dn": [4]}, {"tok": "wearing", "tag": "VBG", "dep": "pcomp", "up": 3, "dn": [5]}, {"tok": "pastels", "tag": "NNS", "dep": "dobj", "up": 4, "dn": []}, {"tok": "?", "tag": ".", "dep": "punct", "up": 0, "dn": []}]}]}, "reply-to": "L868", "timestamp": null, "vectors": []}\n'

# %% [markdown]
# Create formatted data file
# ==========================
#
# For convenience, we\'ll create a nicely formatted data file in which
# each line contains a tab-separated *query sentence* and a *response
# sentence* pair.
#
# The following functions facilitate the parsing of the raw
# `utterances.jsonl` data file.
#
# -   `loadLinesAndConversations` splits each line of the file into a
#     dictionary of lines with fields: `lineID`, `characterID`, and text
#     and then groups them into conversations with fields:
#     `conversationID`, `movieID`, and lines.
# -   `extractSentencePairs` extracts pairs of sentences from
#     conversations

# %%
# Splits each line of the file to create lines and conversations
def loadLinesAndConversations(fileName):
    lines = {}
    conversations = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            lineJson = json.loads(line)
            # Extract fields for line object
            lineObj = {}
            lineObj["lineID"] = lineJson["id"]
            lineObj["characterID"] = lineJson["speaker"]
            lineObj["text"] = lineJson["text"]
            lines[lineObj['lineID']] = lineObj

            # Extract fields for conversation object
            if lineJson["conversation_id"] not in conversations:
                convObj = {}
                convObj["conversationID"] = lineJson["conversation_id"]
                convObj["movieID"] = lineJson["meta"]["movie_id"]
                convObj["lines"] = [lineObj]
            else:
                convObj = conversations[lineJson["conversation_id"]]
                convObj["lines"].insert(0, lineObj)
            conversations[convObj["conversationID"]] = convObj

    return lines, conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations.values():
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %% [markdown]
# Now we'll call these functions and create the file. We'll call it
# `formatted_movie_lines.txt`.

# %%
# Define path to new file
datafile = os.path.join(corpus, "formatted_movie_lines.txt")

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict and conversations dict
lines = {}
conversations = {}
# Load lines and conversations
print("\nProcessing corpus into lines and conversations...")
lines, conversations = loadLinesAndConversations(os.path.join(corpus, "utterances.jsonl"))

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus into lines and conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b'They do to!\tThey do not!\n'
# b'She okay?\tI hope so.\n'
# b"Wow\tLet's go.\n"
# b'"I\'m kidding.  You know how sometimes you just become this ""persona""?  And you don\'t know how to quit?"\tNo\n'
# b"No\tOkay -- you're gonna need to learn how to lie.\n"
# b"I figured you'd get to the good stuff eventually.\tWhat good stuff?\n"
# b'What good stuff?\t"The ""real you""."\n'
# b'"The ""real you""."\tLike my fear of wearing pastels?\n'
# b'do you listen to this crap?\tWhat crap?\n'
# b"What crap?\tMe.  This endless ...blonde babble. I'm like, boring myself.\n"

# %% [markdown]
# Load and trim data
# ==================
#
# Our next order of business is to create a vocabulary and load
# query/response sentence pairs into memory.
#
# Note that we are dealing with sequences of **words**, which do not have
# an implicit mapping to a discrete numerical space. Thus, we must create
# one by mapping each unique word that we encounter in our dataset to an
# index value.
#
# For this we define a `Voc` class, which keeps a mapping from words to
# indexes, a reverse mapping of indexes to words, a count of each word and
# a total word count. The class provides methods for adding a word to the
# vocabulary (`addWord`), adding all words in a sentence (`addSentence`)
# and trimming infrequently seen words (`trim`). More on trimming later.

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %% [markdown]
# Now we can assemble our vocabulary and query/response sentence pairs.
# Before we are ready to use this data, we must perform some
# preprocessing.
#
# First, we must convert the Unicode strings to ASCII using
# `unicodeToAscii`. Next, we should convert all letters to lowercase and
# trim all non-letter characters except for basic punctuation
# (`normalizeString`). Finally, to aid in training convergence, we will
# filter out sentences with length greater than the `MAX_LENGTH` threshold
# (`filterPairs`).

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True if both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using the ``filterPair`` condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("/content/drive/MyDrive/chatbot tutorial", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64313 sentence pairs
# Counting words...
# Counted words: 18082
#
# pairs:
# ['they do to !', 'they do not !']
# ['she okay ?', 'i hope so .']
# ['wow', 'let s go .']
# ['what good stuff ?', 'the real you .']
# ['the real you .', 'like my fear of wearing pastels ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['have fun tonight ?', 'tons']

# %% [markdown]
# Another tactic that is beneficial to achieving faster convergence during
# training is trimming rarely used words out of our vocabulary. Decreasing
# the feature space will also soften the difficulty of the function that
# the model must learn to approximate. We will do this as a two-step
# process:
#
# 1)  Trim words used under `MIN_COUNT` threshold using the `voc.trim`
#     function.
# 2)  Filter out pairs with trimmed words.

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7833 / 18079 = 0.4333
# Trimmed from 64313 pairs to 53131, 0.8261 of total

# %% [markdown]
# Prepare Data for Models
# =======================
#
# Although we have put a great deal of effort into preparing and massaging
# our data into a nice vocabulary object and list of sentence pairs, our
# models will ultimately expect numerical torch tensors as inputs. One way
# to prepare the processed data for the models can be found in the
# [seq2seq translation
# tutorial](https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html).
# In that tutorial, we use a batch size of 1, meaning that all we have to
# do is convert the words in our sentence pairs to their corresponding
# indexes from the vocabulary and feed this to the models.
#
# However, if you're interested in speeding up training and/or would like
# to leverage GPU parallelization capabilities, you will need to train
# with mini-batches.
#
# Using mini-batches also means that we must be mindful of the variation
# of sentence length in our batches. To accommodate sentences of different
# sizes in the same batch, we will make our batched input tensor of shape
# *(max\_length, batch\_size)*, where sentences shorter than the
# *max\_length* are zero padded after an *EOS\_token*.
#
# If we simply convert our English sentences to tensors by converting
# words to their indexes(`indexesFromSentence`) and zero-pad, our tensor
# would have shape *(batch\_size, max\_length)* and indexing the first
# dimension would return a full sequence across all time-steps. However,
# we need to be able to index our batch along time, and across all
# sequences in the batch. Therefore, we transpose our input batch shape to
# *(max\_length, batch\_size)*, so that indexing across the first
# dimension returns a time step across all sentences in the batch. We
# handle this transpose implicitly in the `zeroPadding` function.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/seq2seq_batches.png){.align-center}
#
# The `inputVar` function handles the process of converting sentences to
# tensor, ultimately creating a correctly shaped zero-padded tensor. It
# also returns a tensor of `lengths` for each of the sequences in the
# batch which will be passed to our decoder later.
#
# The `outputVar` function performs a similar function to `inputVar`, but
# instead of returning a `lengths` tensor, it returns a binary mask tensor
# and a maximum target sentence length. The binary mask tensor has the
# same shape as the output target tensor, but every element that is a
# *PAD\_token* is 0 and all others are 1.
#
# `batch2TrainData` simply takes a bunch of pairs and returns the input
# and target tensors using the aforementioned functions.

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[   8,  132, 2502,    4, 1044],
#         [ 111,    8,   22,   24,  217],
#         [ 135, 1418, 3976,  665,   14],
#         [ 523,   24,   11,   83,    2],
#         [   5,   64,  208,  748,    0],
#         [  24, 6033,  135,   77,    0],
#         [ 284,   72,   48,   85,    0],
#         [ 112,   10,   14,   10,    0],
#         [  14,    2,    2,    2,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([10,  9,  9,  9,  4])
# target_variable: tensor([[ 103,  284,   34,  104,  146],
#         [  10,   14,    7,  105,   14],
#         [   2,    2,   36,   66,    2],
#         [   0,    0,   14, 7585,    0],
#         [   0,    0,    2,   14,    0],
#         [   0,    0,    0,    2,    0]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [False, False,  True,  True, False],
#         [False, False,  True,  True, False],
#         [False, False, False,  True, False]])
# max_target_len: 6

# %% [markdown]
# Define Models
# =============
#
# Seq2Seq Model
# -------------
#
# The brains of our chatbot is a sequence-to-sequence (seq2seq) model. The
# goal of a seq2seq model is to take a variable-length sequence as an
# input, and return a variable-length sequence as an output using a
# fixed-sized model.
#
# [Sutskever et al.](https://arxiv.org/abs/1409.3215) discovered that by
# using two separate recurrent neural nets together, we can accomplish
# this task. One RNN acts as an **encoder**, which encodes a variable
# length input sequence to a fixed-length context vector. In theory, this
# context vector (the final hidden layer of the RNN) will contain semantic
# information about the query sentence that is input to the bot. The
# second RNN is a **decoder**, which takes an input word and the context
# vector, and returns a guess for the next word in the sequence and a
# hidden state to use in the next iteration.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/seq2seq_ts.png){.align-center}
#
# Image source:
# <https://jeddy92.github.io/JEddy92.github.io/ts_seq2seq_intro/>

# %% [markdown]
# Encoder
# =======
#
# The encoder RNN iterates through the input sentence one token
# (e.g. word) at a time, at each time step outputting an "output" vector
# and a "hidden state" vector. The hidden state vector is then passed to
# the next time step, while the output vector is recorded. The encoder
# transforms the context it saw at each point in the sequence into a set
# of points in a high-dimensional space, which the decoder will use to
# generate a meaningful output for the given task.
#
# At the heart of our encoder is a multi-layered Gated Recurrent Unit,
# invented by [Cho et al.](https://arxiv.org/pdf/1406.1078v3.pdf) in 2014.
# We will use a bidirectional variant of the GRU, meaning that there are
# essentially two independent RNNs: one that is fed the input sequence in
# normal sequential order, and one that is fed the input sequence in
# reverse order. The outputs of each network are summed at each time step.
# Using a bidirectional GRU will give us the advantage of encoding both
# past and future contexts.
#
# Bidirectional RNN:
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/RNN-bidirectional.png){.align-center
# width="70.0%"}
#
# Image source: <https://colah.github.io/posts/2015-09-NN-Types-FP/>
#
# Note that an `embedding` layer is used to encode our word indices in an
# arbitrarily sized feature space. For our models, this layer will map
# each word to a feature space of size *hidden\_size*. When trained, these
# values should encode semantic similarity between similar meaning words.
#
# Finally, if passing a padded batch of sequences to an RNN module, we
# must pack and unpack padding around the RNN pass using
# `nn.utils.rnn.pack_padded_sequence` and
# `nn.utils.rnn.pad_packed_sequence` respectively.
#
# **Computation Graph:**
#
# > 1)  Convert word indexes to embeddings.
# > 2)  Pack padded batch of sequences for RNN module.
# > 3)  Forward pass through GRU.
# > 4)  Unpack padding.
# > 5)  Sum bidirectional GRU outputs.
# > 6)  Return output and final hidden state.
#
# **Inputs:**
#
# -   `input_seq`: batch of input sentences; shape=*(max\_length,
#     batch\_size)*
# -   `input_lengths`: list of sentence lengths corresponding to each
#     sentence in the batch; shape=*(batch\_size)*
# -   `hidden`: hidden state; shape=*(n\_layers x num\_directions,
#     batch\_size, hidden\_size)*
#
# **Outputs:**
#
# -   `outputs`: output features from the last hidden layer of the GRU
#     (sum of bidirectional outputs); shape=*(max\_length, batch\_size,
#     hidden\_size)*
# -   `hidden`: updated hidden state from GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size parameters are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %% [markdown]
# Decoder
# =======
#
# The decoder RNN generates the response sentence in a token-by-token
# fashion. It uses the encoder's context vectors, and internal hidden
# states to generate the next word in the sequence. It continues
# generating words until it outputs an *EOS\_token*, representing the end
# of the sentence. A common problem with a vanilla seq2seq decoder is that
# if we rely solely on the context vector to encode the entire input
# sequence's meaning, it is likely that we will have information loss.
# This is especially the case when dealing with long input sequences,
# greatly limiting the capability of our decoder.
#
# To combat this, [Bahdanau et al.](https://arxiv.org/abs/1409.0473)
# created an "attention mechanism" that allows the decoder to pay
# attention to certain parts of the input sequence, rather than using the
# entire fixed context at every step.
#
# At a high level, attention is calculated using the decoder's current
# hidden state and the encoder's outputs. The output attention weights
# have the same shape as the input sequence, allowing us to multiply them
# by the encoder outputs, giving us a weighted sum which indicates the
# parts of encoder output to pay attention to. [Sean
# Robertson's](https://github.com/spro) figure describes this very well:
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/attn2.png){.align-center}
#
# [Luong et al.](https://arxiv.org/abs/1508.04025) improved upon Bahdanau
# et al.'s groundwork by creating "Global attention". The key difference
# is that with "Global attention", we consider all of the encoder's hidden
# states, as opposed to Bahdanau et al.'s "Local attention", which only
# considers the encoder's hidden state from the current time step. Another
# difference is that with "Global attention", we calculate attention
# weights, or energies, using the hidden state of the decoder from the
# current time step only. Bahdanau et al.'s attention calculation requires
# knowledge of the decoder's state from the previous time step. Also,
# Luong et al. provides various methods to calculate the attention
# energies between the encoder output and decoder output which are called
# "score functions":
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/scores.png){.align-center
# width="60.0%"}
#
# where $h_t$ = current target decoder state and $\bar{h}_s$ = all encoder
# states.
#
# Overall, the Global attention mechanism can be summarized by the
# following figure. Note that we will implement the "Attention Layer" as a
# separate `nn.Module` called `Attn`. The output of this module is a
# softmax normalized weights tensor of shape *(batch\_size, 1,
# max\_length)*.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/global_attn.png){.align-center
# width="60.0%"}

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %% [markdown]
# Now that we have defined our attention submodule, we can implement the
# actual decoder model. For the decoder, we will manually feed our batch
# one time step at a time. This means that our embedded word tensor and
# GRU output will both have shape *(1, batch\_size, hidden\_size)*.
#
# **Computation Graph:**
#
# > 1)  Get embedding of current input word.
# > 2)  Forward through unidirectional GRU.
# > 3)  Calculate attention weights from the current GRU output from (2).
# > 4)  Multiply attention weights to encoder outputs to get new
# >     \"weighted sum\" context vector.
# > 5)  Concatenate weighted context vector and GRU output using Luong
# >     eq. 5.
# > 6)  Predict next word using Luong eq. 6 (without softmax).
# > 7)  Return output and final hidden state.
#
# **Inputs:**
#
# -   `input_step`: one time step (one word) of input sequence batch;
#     shape=*(1, batch\_size)*
# -   `last_hidden`: final hidden layer of GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*
# -   `encoder_outputs`: encoder model's output; shape=*(max\_length,
#     batch\_size, hidden\_size)*
#
# **Outputs:**
#
# -   `output`: softmax normalized tensor giving probabilities of each
#     word being the correct next word in the decoded sequence;
#     shape=*(batch\_size, voc.num\_words)*
# -   `hidden`: final hidden state of GRU; shape=*(n\_layers x
#     num\_directions, batch\_size, hidden\_size)*

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %% [markdown]
# Define Training Procedure
# =========================
#
# Masked loss
# -----------
#
# Since we are dealing with batches of padded sequences, we cannot simply
# consider all elements of the tensor when calculating loss. We define
# `maskNLLLoss` to calculate our loss based on our decoder's output
# tensor, the target tensor, and a binary mask tensor describing the
# padding of the target tensor. This loss function calculates the average
# negative log likelihood of the elements that correspond to a *1* in the
# mask tensor.

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %% [markdown]
# Single training iteration
# =========================
#
# The `train` function contains the algorithm for a single training
# iteration (a single batch of inputs).
#
# We will use a couple of clever tricks to aid in convergence:
#
# -   The first trick is using **teacher forcing**. This means that at
#     some probability, set by `teacher_forcing_ratio`, we use the current
#     target word as the decoder's next input rather than using the
#     decoder's current guess. This technique acts as training wheels for
#     the decoder, aiding in more efficient training. However, teacher
#     forcing can lead to model instability during inference, as the
#     decoder may not have a sufficient chance to truly craft its own
#     output sequences during training. Thus, we must be mindful of how we
#     are setting the `teacher_forcing_ratio`, and not be fooled by fast
#     convergence.
# -   The second trick that we implement is **gradient clipping**. This is
#     a commonly used technique for countering the "exploding gradient"
#     problem. In essence, by clipping or thresholding gradients to a
#     maximum value, we prevent the gradients from growing exponentially
#     and either overflow (NaN), or overshoot steep cliffs in the cost
#     function.
#
# ![](https://pytorch.org/tutorials/_static/img/chatbot/grad_clip.png){.align-center
# width="60.0%"}
#
# Image source: Goodfellow et al. *Deep Learning*. 2016.
# <https://www.deeplearningbook.org/>
#
# **Sequence of Operations:**
#
# > 1)  Forward pass entire input batch through encoder.
# > 2)  Initialize decoder inputs as SOS\_token, and hidden state as the
# >     encoder\'s final hidden state.
# > 3)  Forward input batch sequence through decoder one time step at a
# >     time.
# > 4)  If teacher forcing: set next decoder input as the current target;
# >     else: set next decoder input as current decoder output.
# > 5)  Calculate and accumulate loss.
# > 6)  Perform backpropagation.
# > 7)  Clip gradients.
# > 8)  Update encoder and decoder model parameters.

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %% [markdown]
# Training iterations
# ===================
#
# It is finally time to tie the full training procedure together with the
# data. The `trainIters` function is responsible for running
# `n_iterations` of training given the passed models, optimizers, data,
# etc. This function is quite self explanatory, as we have done the heavy
# lifting with the `train` function.
#
# One thing to note is that when we save our model, we save a tarball
# containing the encoder and decoder `state_dicts` (parameters), the
# optimizers' `state_dicts`, the loss, the iteration, etc. Saving the
# model in this way will give us the ultimate flexibility with the
# checkpoint. After loading a checkpoint, we will be able to use the model
# parameters to run inference, or we can continue training right where we
# left off.

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename:
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %% [markdown]
# Define Evaluation
# =================
#
# After training a model, we want to be able to talk to the bot ourselves.
# First, we must define how we want the model to decode the encoded input.
#
# Greedy decoding
# ---------------
#
# Greedy decoding is the decoding method that we use during training when
# we are **NOT** using teacher forcing. In other words, for each time
# step, we simply choose the word from `decoder_output` with the highest
# softmax value. This decoding method is optimal on a single time-step
# level.
#
# To facilitate the greedy decoding operation, we define a
# `GreedySearchDecoder` class. When run, an object of this class takes an
# input sequence (`input_seq`) of shape *(input\_seq length, 1)*, a scalar
# input length (`input_length`) tensor, and a `max_length` to bound the
# response sentence length. The input sentence is evaluated using the
# following computational graph:
#
# **Computation Graph:**
#
# > 1)  Forward input through encoder model.
# >
# > 2)  Prepare encoder\'s final hidden layer to be first hidden input to
# >     the decoder.
# >
# > 3)  Initialize decoder\'s first input as SOS\_token.
# >
# > 4)  Initialize tensors to append decoded words to.
# >
# > 5)
# >
# >     Iteratively decode one word token at a time:
# >
# >     :   a)  Forward pass through decoder.
# >         b)  Obtain most likely word token and its softmax score.
# >         c)  Record token and score.
# >         d)  Prepare current token to be next decoder input.
# >
# > 6)  Return collections of word tokens and scores.

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:self.decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %% [markdown]
# Evaluate my text
# ================
#
# Now that we have our decoding method defined, we can write functions for
# evaluating a string input sentence. The `evaluate` function manages the
# low-level process of handling the input sentence. We first format the
# sentence as an input batch of word indexes with *batch\_size==1*. We do
# this by converting the words of the sentence to their corresponding
# indexes, and transposing the dimensions to prepare the tensor for our
# models. We also create a `lengths` tensor which contains the length of
# our input sentence. In this case, `lengths` is scalar because we are
# only evaluating one sentence at a time (batch\_size==1). Next, we obtain
# the decoded response sentence tensor using our `GreedySearchDecoder`
# object (`searcher`). Finally, we convert the response's indexes to words
# and return the list of decoded words.
#
# `evaluateInput` acts as the user interface for our chatbot. When called,
# an input text field will spawn in which we can enter our query sentence.
# After typing our input sentence and pressing *Enter*, our text is
# normalized in the same way as our training data, and is ultimately fed
# to the `evaluate` function to obtain a decoded output sentence. We loop
# this process, so we can keep chatting with our bot until we enter either
# "q" or "quit".
#
# Finally, if a sentence is entered that contains a word that is not in
# the vocabulary, we handle this gracefully by printing an error message
# and prompting the user to enter another sentence.

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %% [markdown]
# Run Model
# =========
#
# Finally, it is time to run our model!
#
# Regardless of whether we want to train or test the chatbot model, we
# must initialize the individual encoder and decoder models. In the
# following block, we set our desired configurations, choose to start from
# scratch or set a checkpoint to load from, and build and initialize the
# models. Feel free to play with different model configurations to
# optimize performance.

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
loadFilename = None
checkpoint_iter = 4000

# %% [markdown]
# Sample code to load from a checkpoint:
#
# ``` {.python}
# loadFilename = os.path.join(save_dir, model_name, corpus_name,
#                     '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
#                     '{}_checkpoint.tar'.format(checkpoint_iter))
# ```

# %%
# Load model if a ``loadFilename`` is provided
if loadFilename:
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename:
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename:
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %% [markdown]
# Run Training
# ============
#
# Run the following block if you want to train the model.
#
# First we set training parameters, then we initialize our optimizers, and
# finally we call the `trainIters` function to run our training
# iterations.

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename:
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have an accelerator, configure it to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.to(device)

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.to(device)

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9613
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8473
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6518
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.3518
# Iteration: 5; Percent complete: 0.1%; Average loss: 7.9659
# Iteration: 6; Percent complete: 0.1%; Average loss: 7.3130
# Iteration: 7; Percent complete: 0.2%; Average loss: 6.8905
# Iteration: 8; Percent complete: 0.2%; Average loss: 6.8528
# Iteration: 9; Percent complete: 0.2%; Average loss: 6.8681
# Iteration: 10; Percent complete: 0.2%; Average loss: 6.8061
# Iteration: 11; Percent complete: 0.3%; Average loss: 6.2161
# Iteration: 12; Percent complete: 0.3%; Average loss: 5.9196
# Iteration: 13; Percent complete: 0.3%; Average loss: 5.8913
# Iteration: 14; Percent complete: 0.4%; Average loss: 5.7319
# Iteration: 15; Percent complete: 0.4%; Average loss: 5.7687
# Iteration: 16; Percent complete: 0.4%; Average loss: 5.3268
# Iteration: 17; Percent complete: 0.4%; Average loss: 5.0034
# Iteration: 18; Percent complete: 0.4%; Average loss: 5.1061
# Iteration: 19; Percent complete: 0.5%; Average loss: 4.9414
# Iteration: 20; Percent complete: 0.5%; Average loss: 5.0873
# Iteration: 21; Percent complete: 0.5%; Average loss: 5.0968
# Iteration: 22; Percent complete: 0.5%; Average loss: 5.0219
# Iteration: 23; Percent complete: 0.6%; Average loss: 4.7751
# Iteration: 24; Percent complete: 0.6%; Average loss: 4.8583
# Iteration: 25; Percent complete: 0.6%; Average loss: 4.9514
# Iteration: 26; Percent complete: 0.7%; Average loss: 4.8215
# Iteration: 27; Percent complete: 0.7%; Average loss: 5.0286
# Iteration: 28; Percent complete: 0.7%; Average loss: 4.7751
# Iteration: 29; Percent complete: 0.7%; Average loss: 4.7234
# Iteration: 30; Percent complete: 0.8%; Average loss: 4.8180
# Iteration: 31; Percent complete: 0.8%; Average loss: 4.8047
# Iteration: 32; Percent complete: 0.8%; Average loss: 4.8159
# Iteration: 33; Percent complete: 0.8%; Average loss: 4.6239
# Iteration: 34; Percent complete: 0.9%; Average loss: 4.6443
# Iteration: 35; Percent complete: 0.9%; Average loss: 4.6865
# Iteration: 36; Percent complete: 0.9%; Average loss: 4.6997
# Iteration: 37; Percent complete: 0.9%; Average loss: 4.7451
# Iteration: 38; Percent complete: 0.9%; Average loss: 4.5654
# Iteration: 39; Percent complete: 1.0%; Average loss: 4.7854
# Iteration: 40; Percent complete: 1.0%; Average loss: 4.7837
# Iteration: 41; Percent complete: 1.0%; Average loss: 4.7213
# Iteration: 42; Percent complete: 1.1%; Average loss: 4.4312
# Iteration: 43; Percent complete: 1.1%; Average loss: 4.4053
# Iteration: 44; Percent complete: 1.1%; Average loss: 4.6709
# Iteration: 45; Percent complete: 1.1%; Average loss: 4.5488
# Iteration: 46; Percent complete: 1.1%; Average loss: 4.8132
# Iteration: 47; Percent complete: 1.2%; Average loss: 4.6485
# Iteration: 48; Percent complete: 1.2%; Average loss: 4.7589
# Iteration: 49; Percent complete: 1.2%; Average loss: 4.5078
# Iteration: 50; Percent complete: 1.2%; Average loss: 4.5465
# Iteration: 51; Percent complete: 1.3%; Average loss: 4.5057
# Iteration: 52; Percent complete: 1.3%; Average loss: 4.7666
# Iteration: 53; Percent complete: 1.3%; Average loss: 4.7020
# Iteration: 54; Percent complete: 1.4%; Average loss: 4.6045
# Iteration: 55; Percent complete: 1.4%; Average loss: 4.6934
# Iteration: 56; Percent complete: 1.4%; Average loss: 4.6448
# Iteration: 57; Percent complete: 1.4%; Average loss: 4.7197
# Iteration: 58; Percent complete: 1.5%; Average loss: 4.6129
# Iteration: 59; Percent complete: 1.5%; Average loss: 4.4767
# Iteration: 60; Percent complete: 1.5%; Average loss: 4.6738
# Iteration: 61; Percent complete: 1.5%; Average loss: 4.6073
# Iteration: 62; Percent complete: 1.6%; Average loss: 4.3400
# Iteration: 63; Percent complete: 1.6%; Average loss: 4.7793
# Iteration: 64; Percent complete: 1.6%; Average loss: 4.3913
# Iteration: 65; Percent complete: 1.6%; Average loss: 4.7422
# Iteration: 66; Percent complete: 1.7%; Average loss: 4.6284
# Iteration: 67; Percent complete: 1.7%; Average loss: 4.4835
# Iteration: 68; Percent complete: 1.7%; Average loss: 4.6235
# Iteration: 69; Percent complete: 1.7%; Average loss: 4.6334
# Iteration: 70; Percent complete: 1.8%; Average loss: 4.6563
# Iteration: 71; Percent complete: 1.8%; Average loss: 4.6080
# Iteration: 72; Percent complete: 1.8%; Average loss: 4.5262
# Iteration: 73; Percent complete: 1.8%; Average loss: 4.4073
# Iteration: 74; Percent complete: 1.8%; Average loss: 4.6959
# Iteration: 75; Percent complete: 1.9%; Average loss: 4.5131
# Iteration: 76; Percent complete: 1.9%; Average loss: 4.2563
# Iteration: 77; Percent complete: 1.9%; Average loss: 4.2468
# Iteration: 78; Percent complete: 1.9%; Average loss: 4.7940
# Iteration: 79; Percent complete: 2.0%; Average loss: 4.4520
# Iteration: 80; Percent complete: 2.0%; Average loss: 4.3330
# Iteration: 81; Percent complete: 2.0%; Average loss: 4.2584
# Iteration: 82; Percent complete: 2.1%; Average loss: 4.5239
# Iteration: 83; Percent complete: 2.1%; Average loss: 4.6194
# Iteration: 84; Percent complete: 2.1%; Average loss: 4.4897
# Iteration: 85; Percent complete: 2.1%; Average loss: 4.3234
# Iteration: 86; Percent complete: 2.1%; Average loss: 4.2918
# Iteration: 87; Percent complete: 2.2%; Average loss: 4.5328
# Iteration: 88; Percent complete: 2.2%; Average loss: 4.5008
# Iteration: 89; Percent complete: 2.2%; Average loss: 4.4006
# Iteration: 90; Percent complete: 2.2%; Average loss: 4.3695
# Iteration: 91; Percent complete: 2.3%; Average loss: 4.5537
# Iteration: 92; Percent complete: 2.3%; Average loss: 4.2971
# Iteration: 93; Percent complete: 2.3%; Average loss: 4.5300
# Iteration: 94; Percent complete: 2.4%; Average loss: 4.3034
# Iteration: 95; Percent complete: 2.4%; Average loss: 4.6269
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.4260
# Iteration: 97; Percent complete: 2.4%; Average loss: 4.4866
# Iteration: 98; Percent complete: 2.5%; Average loss: 4.6995
# Iteration: 99; Percent complete: 2.5%; Average loss: 4.3934
# Iteration: 100; Percent complete: 2.5%; Average loss: 4.6359
# Iteration: 101; Percent complete: 2.5%; Average loss: 4.4944
# Iteration: 102; Percent complete: 2.5%; Average loss: 4.2283
# Iteration: 103; Percent complete: 2.6%; Average loss: 4.3248
# Iteration: 104; Percent complete: 2.6%; Average loss: 4.4623
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.4734
# Iteration: 106; Percent complete: 2.6%; Average loss: 4.2243
# Iteration: 107; Percent complete: 2.7%; Average loss: 4.4284
# Iteration: 108; Percent complete: 2.7%; Average loss: 4.3586
# Iteration: 109; Percent complete: 2.7%; Average loss: 4.1040
# Iteration: 110; Percent complete: 2.8%; Average loss: 4.4815
# Iteration: 111; Percent complete: 2.8%; Average loss: 4.3370
# Iteration: 112; Percent complete: 2.8%; Average loss: 4.2684
# Iteration: 113; Percent complete: 2.8%; Average loss: 4.0602
# Iteration: 114; Percent complete: 2.9%; Average loss: 4.2411
# Iteration: 115; Percent complete: 2.9%; Average loss: 4.3376
# Iteration: 116; Percent complete: 2.9%; Average loss: 4.1312
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.2682
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.3067
# Iteration: 119; Percent complete: 3.0%; Average loss: 4.2936
# Iteration: 120; Percent complete: 3.0%; Average loss: 4.5606
# Iteration: 121; Percent complete: 3.0%; Average loss: 4.4122
# Iteration: 122; Percent complete: 3.0%; Average loss: 4.3292
# Iteration: 123; Percent complete: 3.1%; Average loss: 4.4113
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.3958
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.3918
# Iteration: 126; Percent complete: 3.1%; Average loss: 4.2849
# Iteration: 127; Percent complete: 3.2%; Average loss: 4.0715
# Iteration: 128; Percent complete: 3.2%; Average loss: 4.3245
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.3857
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.2990
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.1666
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.5823
# Iteration: 133; Percent complete: 3.3%; Average loss: 3.9797
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.2718
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.1407
# Iteration: 136; Percent complete: 3.4%; Average loss: 4.1464
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.4040
# Iteration: 138; Percent complete: 3.5%; Average loss: 4.2639
# Iteration: 139; Percent complete: 3.5%; Average loss: 4.3315
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.2512
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.2925
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.2409
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.2246
# Iteration: 144; Percent complete: 3.6%; Average loss: 4.4718
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.2619
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.2148
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.3076
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.4632
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.0397
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.1133
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.0669
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.1136
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.1094
# Iteration: 154; Percent complete: 3.9%; Average loss: 4.0586
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.3710
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.2327
# Iteration: 157; Percent complete: 3.9%; Average loss: 4.1375
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.1725
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.4904
# Iteration: 160; Percent complete: 4.0%; Average loss: 3.9421
# Iteration: 161; Percent complete: 4.0%; Average loss: 3.9925
# Iteration: 162; Percent complete: 4.0%; Average loss: 4.3242
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.3818
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.1546
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.0164
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.3082
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.2823
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.1941
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.3077
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.1045
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.1865
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.0948
# Iteration: 173; Percent complete: 4.3%; Average loss: 3.9701
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.1024
# Iteration: 175; Percent complete: 4.4%; Average loss: 4.2810
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.2489
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.1620
# Iteration: 178; Percent complete: 4.5%; Average loss: 3.9912
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.3995
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.2861
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.2738
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.0807
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.0425
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.0807
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.2459
# Iteration: 186; Percent complete: 4.7%; Average loss: 3.9252
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.0627
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.0491
# Iteration: 189; Percent complete: 4.7%; Average loss: 3.9727
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.1190
# Iteration: 191; Percent complete: 4.8%; Average loss: 4.0542
# Iteration: 192; Percent complete: 4.8%; Average loss: 4.0159
# Iteration: 193; Percent complete: 4.8%; Average loss: 4.0198
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.1450
# Iteration: 195; Percent complete: 4.9%; Average loss: 3.9537
# Iteration: 196; Percent complete: 4.9%; Average loss: 3.8540
# Iteration: 197; Percent complete: 4.9%; Average loss: 3.9474
# Iteration: 198; Percent complete: 5.0%; Average loss: 3.9851
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.2663
# Iteration: 200; Percent complete: 5.0%; Average loss: 3.9599
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.0167
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.1466
# Iteration: 203; Percent complete: 5.1%; Average loss: 4.5134
# Iteration: 204; Percent complete: 5.1%; Average loss: 3.9645
# Iteration: 205; Percent complete: 5.1%; Average loss: 4.0884
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.0836
# Iteration: 207; Percent complete: 5.2%; Average loss: 3.9987
# Iteration: 208; Percent complete: 5.2%; Average loss: 3.6761
# Iteration: 209; Percent complete: 5.2%; Average loss: 4.0408
# Iteration: 210; Percent complete: 5.2%; Average loss: 3.8905
# Iteration: 211; Percent complete: 5.3%; Average loss: 4.1306
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.2713
# Iteration: 213; Percent complete: 5.3%; Average loss: 3.9501
# Iteration: 214; Percent complete: 5.3%; Average loss: 4.0287
# Iteration: 215; Percent complete: 5.4%; Average loss: 3.9354
# Iteration: 216; Percent complete: 5.4%; Average loss: 4.1487
# Iteration: 217; Percent complete: 5.4%; Average loss: 3.9902
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.1151
# Iteration: 219; Percent complete: 5.5%; Average loss: 4.0097
# Iteration: 220; Percent complete: 5.5%; Average loss: 4.3669
# Iteration: 221; Percent complete: 5.5%; Average loss: 3.9067
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.3656
# Iteration: 223; Percent complete: 5.6%; Average loss: 4.0198
# Iteration: 224; Percent complete: 5.6%; Average loss: 4.0497
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.2781
# Iteration: 226; Percent complete: 5.7%; Average loss: 4.1255
# Iteration: 227; Percent complete: 5.7%; Average loss: 3.9236
# Iteration: 228; Percent complete: 5.7%; Average loss: 4.1668
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.2227
# Iteration: 230; Percent complete: 5.8%; Average loss: 4.0356
# Iteration: 231; Percent complete: 5.8%; Average loss: 4.1825
# Iteration: 232; Percent complete: 5.8%; Average loss: 3.8455
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.1967
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.1113
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.1496
# Iteration: 236; Percent complete: 5.9%; Average loss: 3.8459
# Iteration: 237; Percent complete: 5.9%; Average loss: 3.8628
# Iteration: 238; Percent complete: 5.9%; Average loss: 4.0012
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.0516
# Iteration: 240; Percent complete: 6.0%; Average loss: 4.1956
# Iteration: 241; Percent complete: 6.0%; Average loss: 4.0058
# Iteration: 242; Percent complete: 6.0%; Average loss: 4.0250
# Iteration: 243; Percent complete: 6.1%; Average loss: 3.6898
# Iteration: 244; Percent complete: 6.1%; Average loss: 4.1462
# Iteration: 245; Percent complete: 6.1%; Average loss: 4.0079
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.8393
# Iteration: 247; Percent complete: 6.2%; Average loss: 3.9860
# Iteration: 248; Percent complete: 6.2%; Average loss: 3.8611
# Iteration: 249; Percent complete: 6.2%; Average loss: 3.9965
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.0433
# Iteration: 251; Percent complete: 6.3%; Average loss: 3.9125
# Iteration: 252; Percent complete: 6.3%; Average loss: 3.9504
# Iteration: 253; Percent complete: 6.3%; Average loss: 3.9172
# Iteration: 254; Percent complete: 6.3%; Average loss: 3.8311
# Iteration: 255; Percent complete: 6.4%; Average loss: 4.1110
# Iteration: 256; Percent complete: 6.4%; Average loss: 3.7670
# Iteration: 257; Percent complete: 6.4%; Average loss: 3.8356
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.0976
# Iteration: 259; Percent complete: 6.5%; Average loss: 4.0407
# Iteration: 260; Percent complete: 6.5%; Average loss: 3.7649
# Iteration: 261; Percent complete: 6.5%; Average loss: 3.8996
# Iteration: 262; Percent complete: 6.6%; Average loss: 3.8702
# Iteration: 263; Percent complete: 6.6%; Average loss: 3.7676
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.0371
# Iteration: 265; Percent complete: 6.6%; Average loss: 3.9303
# Iteration: 266; Percent complete: 6.7%; Average loss: 3.8824
# Iteration: 267; Percent complete: 6.7%; Average loss: 4.0464
# Iteration: 268; Percent complete: 6.7%; Average loss: 4.1058
# Iteration: 269; Percent complete: 6.7%; Average loss: 4.0795
# Iteration: 270; Percent complete: 6.8%; Average loss: 3.7174
# Iteration: 271; Percent complete: 6.8%; Average loss: 4.2334
# Iteration: 272; Percent complete: 6.8%; Average loss: 3.8506
# Iteration: 273; Percent complete: 6.8%; Average loss: 4.1570
# Iteration: 274; Percent complete: 6.9%; Average loss: 3.9093
# Iteration: 275; Percent complete: 6.9%; Average loss: 4.0542
# Iteration: 276; Percent complete: 6.9%; Average loss: 3.8862
# Iteration: 277; Percent complete: 6.9%; Average loss: 3.8914
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.8266
# Iteration: 279; Percent complete: 7.0%; Average loss: 3.9233
# Iteration: 280; Percent complete: 7.0%; Average loss: 4.0127
# Iteration: 281; Percent complete: 7.0%; Average loss: 4.1147
# Iteration: 282; Percent complete: 7.0%; Average loss: 3.9747
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.0819
# Iteration: 284; Percent complete: 7.1%; Average loss: 4.1114
# Iteration: 285; Percent complete: 7.1%; Average loss: 4.1658
# Iteration: 286; Percent complete: 7.1%; Average loss: 3.9730
# Iteration: 287; Percent complete: 7.2%; Average loss: 3.9635
# Iteration: 288; Percent complete: 7.2%; Average loss: 3.7340
# Iteration: 289; Percent complete: 7.2%; Average loss: 3.8637
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.2329
# Iteration: 291; Percent complete: 7.3%; Average loss: 3.9286
# Iteration: 292; Percent complete: 7.3%; Average loss: 4.0735
# Iteration: 293; Percent complete: 7.3%; Average loss: 4.1093
# Iteration: 294; Percent complete: 7.3%; Average loss: 3.7384
# Iteration: 295; Percent complete: 7.4%; Average loss: 4.0248
# Iteration: 296; Percent complete: 7.4%; Average loss: 3.8842
# Iteration: 297; Percent complete: 7.4%; Average loss: 3.7680
# Iteration: 298; Percent complete: 7.4%; Average loss: 4.2916
# Iteration: 299; Percent complete: 7.5%; Average loss: 4.0474
# Iteration: 300; Percent complete: 7.5%; Average loss: 3.8695
# Iteration: 301; Percent complete: 7.5%; Average loss: 3.8248
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.8464
# Iteration: 303; Percent complete: 7.6%; Average loss: 4.0067
# Iteration: 304; Percent complete: 7.6%; Average loss: 3.9801
# Iteration: 305; Percent complete: 7.6%; Average loss: 3.9493
# Iteration: 306; Percent complete: 7.6%; Average loss: 3.9847
# Iteration: 307; Percent complete: 7.7%; Average loss: 4.0479
# Iteration: 308; Percent complete: 7.7%; Average loss: 3.9202
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.9346
# Iteration: 310; Percent complete: 7.8%; Average loss: 4.1477
# Iteration: 311; Percent complete: 7.8%; Average loss: 3.7022
# Iteration: 312; Percent complete: 7.8%; Average loss: 3.7298
# Iteration: 313; Percent complete: 7.8%; Average loss: 3.7757
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.2819
# Iteration: 315; Percent complete: 7.9%; Average loss: 4.0322
# Iteration: 316; Percent complete: 7.9%; Average loss: 3.8109
# Iteration: 317; Percent complete: 7.9%; Average loss: 3.8082
# Iteration: 318; Percent complete: 8.0%; Average loss: 4.0057
# Iteration: 319; Percent complete: 8.0%; Average loss: 4.1592
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.6479
# Iteration: 321; Percent complete: 8.0%; Average loss: 3.8174
# Iteration: 322; Percent complete: 8.1%; Average loss: 4.1186
# Iteration: 323; Percent complete: 8.1%; Average loss: 3.7429
# Iteration: 324; Percent complete: 8.1%; Average loss: 3.8458
# Iteration: 325; Percent complete: 8.1%; Average loss: 4.0133
# Iteration: 326; Percent complete: 8.2%; Average loss: 3.8110
# Iteration: 327; Percent complete: 8.2%; Average loss: 3.5286
# Iteration: 328; Percent complete: 8.2%; Average loss: 4.1252
# Iteration: 329; Percent complete: 8.2%; Average loss: 4.0404
# Iteration: 330; Percent complete: 8.2%; Average loss: 3.9150
# Iteration: 331; Percent complete: 8.3%; Average loss: 3.7084
# Iteration: 332; Percent complete: 8.3%; Average loss: 4.0354
# Iteration: 333; Percent complete: 8.3%; Average loss: 3.9971
# Iteration: 334; Percent complete: 8.3%; Average loss: 4.0952
# Iteration: 335; Percent complete: 8.4%; Average loss: 3.8806
# Iteration: 336; Percent complete: 8.4%; Average loss: 3.8866
# Iteration: 337; Percent complete: 8.4%; Average loss: 3.6976
# Iteration: 338; Percent complete: 8.5%; Average loss: 3.9274
# Iteration: 339; Percent complete: 8.5%; Average loss: 3.6478
# Iteration: 340; Percent complete: 8.5%; Average loss: 3.9478
# Iteration: 341; Percent complete: 8.5%; Average loss: 3.7488
# Iteration: 342; Percent complete: 8.6%; Average loss: 3.7458
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.7573
# Iteration: 344; Percent complete: 8.6%; Average loss: 3.5847
# Iteration: 345; Percent complete: 8.6%; Average loss: 3.7180
# Iteration: 346; Percent complete: 8.6%; Average loss: 3.8727
# Iteration: 347; Percent complete: 8.7%; Average loss: 3.5413
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.6651
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.9443
# Iteration: 350; Percent complete: 8.8%; Average loss: 3.9141
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.8369
# Iteration: 352; Percent complete: 8.8%; Average loss: 3.7696
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.7094
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.8785
# Iteration: 355; Percent complete: 8.9%; Average loss: 4.1020
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.9592
# Iteration: 357; Percent complete: 8.9%; Average loss: 3.5761
# Iteration: 358; Percent complete: 8.9%; Average loss: 4.0898
# Iteration: 359; Percent complete: 9.0%; Average loss: 4.2642
# Iteration: 360; Percent complete: 9.0%; Average loss: 3.8806
# Iteration: 361; Percent complete: 9.0%; Average loss: 3.8601
# Iteration: 362; Percent complete: 9.0%; Average loss: 3.8360
# Iteration: 363; Percent complete: 9.1%; Average loss: 4.2984
# Iteration: 364; Percent complete: 9.1%; Average loss: 4.0350
# Iteration: 365; Percent complete: 9.1%; Average loss: 3.6803
# Iteration: 366; Percent complete: 9.2%; Average loss: 3.9955
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.8049
# Iteration: 368; Percent complete: 9.2%; Average loss: 3.7240
# Iteration: 369; Percent complete: 9.2%; Average loss: 4.0090
# Iteration: 370; Percent complete: 9.2%; Average loss: 4.0234
# Iteration: 371; Percent complete: 9.3%; Average loss: 3.8605
# Iteration: 372; Percent complete: 9.3%; Average loss: 3.9316
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.9103
# Iteration: 374; Percent complete: 9.3%; Average loss: 3.8302
# Iteration: 375; Percent complete: 9.4%; Average loss: 3.9184
# Iteration: 376; Percent complete: 9.4%; Average loss: 3.8193
# Iteration: 377; Percent complete: 9.4%; Average loss: 3.8288
# Iteration: 378; Percent complete: 9.4%; Average loss: 3.9853
# Iteration: 379; Percent complete: 9.5%; Average loss: 4.0192
# Iteration: 380; Percent complete: 9.5%; Average loss: 3.8199
# Iteration: 381; Percent complete: 9.5%; Average loss: 3.8838
# Iteration: 382; Percent complete: 9.6%; Average loss: 4.0705
# Iteration: 383; Percent complete: 9.6%; Average loss: 4.0110
# Iteration: 384; Percent complete: 9.6%; Average loss: 3.7980
# Iteration: 385; Percent complete: 9.6%; Average loss: 3.9685
# Iteration: 386; Percent complete: 9.7%; Average loss: 4.0376
# Iteration: 387; Percent complete: 9.7%; Average loss: 3.6822
# Iteration: 388; Percent complete: 9.7%; Average loss: 3.8242
# Iteration: 389; Percent complete: 9.7%; Average loss: 3.8131
# Iteration: 390; Percent complete: 9.8%; Average loss: 3.6953
# Iteration: 391; Percent complete: 9.8%; Average loss: 3.7574
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.9160
# Iteration: 393; Percent complete: 9.8%; Average loss: 3.9525
# Iteration: 394; Percent complete: 9.8%; Average loss: 3.6608
# Iteration: 395; Percent complete: 9.9%; Average loss: 3.6137
# Iteration: 396; Percent complete: 9.9%; Average loss: 3.6794
# Iteration: 397; Percent complete: 9.9%; Average loss: 3.9014
# Iteration: 398; Percent complete: 10.0%; Average loss: 3.8853
# Iteration: 399; Percent complete: 10.0%; Average loss: 3.7788
# Iteration: 400; Percent complete: 10.0%; Average loss: 4.1605
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.7755
# Iteration: 402; Percent complete: 10.1%; Average loss: 3.7077
# Iteration: 403; Percent complete: 10.1%; Average loss: 3.8299
# Iteration: 404; Percent complete: 10.1%; Average loss: 3.8208
# Iteration: 405; Percent complete: 10.1%; Average loss: 3.7295
# Iteration: 406; Percent complete: 10.2%; Average loss: 3.9311
# Iteration: 407; Percent complete: 10.2%; Average loss: 3.8407
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.8966
# Iteration: 409; Percent complete: 10.2%; Average loss: 3.9622
# Iteration: 410; Percent complete: 10.2%; Average loss: 3.9359
# Iteration: 411; Percent complete: 10.3%; Average loss: 3.6405
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.7275
# Iteration: 413; Percent complete: 10.3%; Average loss: 3.9187
# Iteration: 414; Percent complete: 10.3%; Average loss: 3.7357
# Iteration: 415; Percent complete: 10.4%; Average loss: 3.7245
# Iteration: 416; Percent complete: 10.4%; Average loss: 3.8118
# Iteration: 417; Percent complete: 10.4%; Average loss: 3.8477
# Iteration: 418; Percent complete: 10.4%; Average loss: 3.9699
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.8331
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.8163
# Iteration: 421; Percent complete: 10.5%; Average loss: 3.6031
# Iteration: 422; Percent complete: 10.5%; Average loss: 3.7102
# Iteration: 423; Percent complete: 10.6%; Average loss: 4.1110
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.8637
# Iteration: 425; Percent complete: 10.6%; Average loss: 3.6440
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.8504
# Iteration: 427; Percent complete: 10.7%; Average loss: 3.6866
# Iteration: 428; Percent complete: 10.7%; Average loss: 3.6284
# Iteration: 429; Percent complete: 10.7%; Average loss: 3.4045
# Iteration: 430; Percent complete: 10.8%; Average loss: 3.7750
# Iteration: 431; Percent complete: 10.8%; Average loss: 3.7201
# Iteration: 432; Percent complete: 10.8%; Average loss: 3.7904
# Iteration: 433; Percent complete: 10.8%; Average loss: 4.0991
# Iteration: 434; Percent complete: 10.8%; Average loss: 3.9268
# Iteration: 435; Percent complete: 10.9%; Average loss: 3.7842
# Iteration: 436; Percent complete: 10.9%; Average loss: 4.0120
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.6845
# Iteration: 438; Percent complete: 10.9%; Average loss: 3.9305
# Iteration: 439; Percent complete: 11.0%; Average loss: 3.7866
# Iteration: 440; Percent complete: 11.0%; Average loss: 3.7071
# Iteration: 441; Percent complete: 11.0%; Average loss: 3.6817
# Iteration: 442; Percent complete: 11.1%; Average loss: 3.6451
# Iteration: 443; Percent complete: 11.1%; Average loss: 3.7956
# Iteration: 444; Percent complete: 11.1%; Average loss: 3.8934
# Iteration: 445; Percent complete: 11.1%; Average loss: 3.7450
# Iteration: 446; Percent complete: 11.2%; Average loss: 3.5946
# Iteration: 447; Percent complete: 11.2%; Average loss: 3.9289
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.4844
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.7391
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.8180
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.8036
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.8527
# Iteration: 453; Percent complete: 11.3%; Average loss: 3.6780
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.6897
# Iteration: 455; Percent complete: 11.4%; Average loss: 3.8638
# Iteration: 456; Percent complete: 11.4%; Average loss: 3.5878
# Iteration: 457; Percent complete: 11.4%; Average loss: 3.8231
# Iteration: 458; Percent complete: 11.5%; Average loss: 3.8510
# Iteration: 459; Percent complete: 11.5%; Average loss: 3.6234
# Iteration: 460; Percent complete: 11.5%; Average loss: 4.0050
# Iteration: 461; Percent complete: 11.5%; Average loss: 3.6933
# Iteration: 462; Percent complete: 11.6%; Average loss: 3.6885
# Iteration: 463; Percent complete: 11.6%; Average loss: 3.7951
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.8057
# Iteration: 465; Percent complete: 11.6%; Average loss: 4.0433
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.7372
# Iteration: 467; Percent complete: 11.7%; Average loss: 3.7703
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.8875
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.5125
# Iteration: 470; Percent complete: 11.8%; Average loss: 3.3486
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.7523
# Iteration: 472; Percent complete: 11.8%; Average loss: 3.8049
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.6769
# Iteration: 474; Percent complete: 11.8%; Average loss: 3.6529
# Iteration: 475; Percent complete: 11.9%; Average loss: 3.5833
# Iteration: 476; Percent complete: 11.9%; Average loss: 3.7384
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.7189
# Iteration: 478; Percent complete: 11.9%; Average loss: 3.8521
# Iteration: 479; Percent complete: 12.0%; Average loss: 3.6057
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.5163
# Iteration: 481; Percent complete: 12.0%; Average loss: 3.9649
# Iteration: 482; Percent complete: 12.0%; Average loss: 3.7007
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.9412
# Iteration: 484; Percent complete: 12.1%; Average loss: 3.6275
# Iteration: 485; Percent complete: 12.1%; Average loss: 3.6981
# Iteration: 486; Percent complete: 12.2%; Average loss: 3.7325
# Iteration: 487; Percent complete: 12.2%; Average loss: 3.5248
# Iteration: 488; Percent complete: 12.2%; Average loss: 3.4234
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.7356
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.7761
# Iteration: 491; Percent complete: 12.3%; Average loss: 3.8412
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.5554
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.4784
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.7598
# Iteration: 495; Percent complete: 12.4%; Average loss: 3.7435
# Iteration: 496; Percent complete: 12.4%; Average loss: 3.6585
# Iteration: 497; Percent complete: 12.4%; Average loss: 3.7994
# Iteration: 498; Percent complete: 12.4%; Average loss: 3.7814
# Iteration: 499; Percent complete: 12.5%; Average loss: 3.5203
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.6522
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.7554
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.6272
# Iteration: 503; Percent complete: 12.6%; Average loss: 3.8289
# Iteration: 504; Percent complete: 12.6%; Average loss: 3.7205
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.7993
# Iteration: 506; Percent complete: 12.7%; Average loss: 3.7346
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.9548
# Iteration: 508; Percent complete: 12.7%; Average loss: 3.7224
# Iteration: 509; Percent complete: 12.7%; Average loss: 3.7641
# Iteration: 510; Percent complete: 12.8%; Average loss: 3.7248
# Iteration: 511; Percent complete: 12.8%; Average loss: 3.7876
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.5556
# Iteration: 513; Percent complete: 12.8%; Average loss: 3.6728
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.3551
# Iteration: 515; Percent complete: 12.9%; Average loss: 3.7158
# Iteration: 516; Percent complete: 12.9%; Average loss: 4.0362
# Iteration: 517; Percent complete: 12.9%; Average loss: 3.6403
# Iteration: 518; Percent complete: 13.0%; Average loss: 3.4111
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.6466
# Iteration: 520; Percent complete: 13.0%; Average loss: 3.7190
# Iteration: 521; Percent complete: 13.0%; Average loss: 3.5141
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.7630
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.7435
# Iteration: 524; Percent complete: 13.1%; Average loss: 3.8352
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.5729
# Iteration: 526; Percent complete: 13.2%; Average loss: 3.7969
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.7019
# Iteration: 528; Percent complete: 13.2%; Average loss: 3.7541
# Iteration: 529; Percent complete: 13.2%; Average loss: 3.9291
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.9401
# Iteration: 531; Percent complete: 13.3%; Average loss: 3.8894
# Iteration: 532; Percent complete: 13.3%; Average loss: 4.2540
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.6982
# Iteration: 534; Percent complete: 13.4%; Average loss: 3.4400
# Iteration: 535; Percent complete: 13.4%; Average loss: 3.4646
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.6703
# Iteration: 537; Percent complete: 13.4%; Average loss: 3.7925
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.3840
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.7427
# Iteration: 540; Percent complete: 13.5%; Average loss: 3.7264
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.6524
# Iteration: 542; Percent complete: 13.6%; Average loss: 3.6568
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.6912
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.5957
# Iteration: 545; Percent complete: 13.6%; Average loss: 3.6742
# Iteration: 546; Percent complete: 13.7%; Average loss: 3.6888
# Iteration: 547; Percent complete: 13.7%; Average loss: 3.7379
# Iteration: 548; Percent complete: 13.7%; Average loss: 3.5670
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.5178
# Iteration: 550; Percent complete: 13.8%; Average loss: 3.9010
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.4814
# Iteration: 552; Percent complete: 13.8%; Average loss: 3.7706
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.6254
# Iteration: 554; Percent complete: 13.9%; Average loss: 3.8522
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.9604
# Iteration: 556; Percent complete: 13.9%; Average loss: 3.5076
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.6578
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.7833
# Iteration: 559; Percent complete: 14.0%; Average loss: 3.7506
# Iteration: 560; Percent complete: 14.0%; Average loss: 3.2751
# Iteration: 561; Percent complete: 14.0%; Average loss: 3.5579
# Iteration: 562; Percent complete: 14.1%; Average loss: 3.8842
# Iteration: 563; Percent complete: 14.1%; Average loss: 3.5098
# Iteration: 564; Percent complete: 14.1%; Average loss: 3.5638
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.5370
# Iteration: 566; Percent complete: 14.1%; Average loss: 3.6683
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.7328
# Iteration: 568; Percent complete: 14.2%; Average loss: 3.8801
# Iteration: 569; Percent complete: 14.2%; Average loss: 3.8047
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.7268
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.8381
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.7863
# Iteration: 573; Percent complete: 14.3%; Average loss: 3.6426
# Iteration: 574; Percent complete: 14.3%; Average loss: 3.6793
# Iteration: 575; Percent complete: 14.4%; Average loss: 3.5512
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.6249
# Iteration: 577; Percent complete: 14.4%; Average loss: 3.4628
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.9248
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.4894
# Iteration: 580; Percent complete: 14.5%; Average loss: 3.8986
# Iteration: 581; Percent complete: 14.5%; Average loss: 3.5453
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.6349
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.7259
# Iteration: 584; Percent complete: 14.6%; Average loss: 3.4087
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.8290
# Iteration: 586; Percent complete: 14.6%; Average loss: 3.7458
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.5281
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.8324
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.5959
# Iteration: 590; Percent complete: 14.8%; Average loss: 3.6726
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.7067
# Iteration: 592; Percent complete: 14.8%; Average loss: 3.5618
# Iteration: 593; Percent complete: 14.8%; Average loss: 3.7959
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.8740
# Iteration: 595; Percent complete: 14.9%; Average loss: 3.4260
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.5388
# Iteration: 597; Percent complete: 14.9%; Average loss: 3.6468
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.5543
# Iteration: 599; Percent complete: 15.0%; Average loss: 3.3379
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.7458
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.5521
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.4848
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.4839
# Iteration: 604; Percent complete: 15.1%; Average loss: 3.6839
# Iteration: 605; Percent complete: 15.1%; Average loss: 3.7379
# Iteration: 606; Percent complete: 15.2%; Average loss: 3.8176
# Iteration: 607; Percent complete: 15.2%; Average loss: 3.6821
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.5999
# Iteration: 609; Percent complete: 15.2%; Average loss: 3.7179
# Iteration: 610; Percent complete: 15.2%; Average loss: 3.6890
# Iteration: 611; Percent complete: 15.3%; Average loss: 3.4398
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.3694
# Iteration: 613; Percent complete: 15.3%; Average loss: 3.8908
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.5527
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.5751
# Iteration: 616; Percent complete: 15.4%; Average loss: 3.4693
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.7733
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.5666
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.5204
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.4163
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.5835
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.6382
# Iteration: 623; Percent complete: 15.6%; Average loss: 3.6134
# Iteration: 624; Percent complete: 15.6%; Average loss: 3.6928
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.5678
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.7127
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.5342
# Iteration: 628; Percent complete: 15.7%; Average loss: 3.5647
# Iteration: 629; Percent complete: 15.7%; Average loss: 3.5625
# Iteration: 630; Percent complete: 15.8%; Average loss: 3.8024
# Iteration: 631; Percent complete: 15.8%; Average loss: 3.7126
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.8162
# Iteration: 633; Percent complete: 15.8%; Average loss: 3.5562
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.4563
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.9634
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.7035
# Iteration: 637; Percent complete: 15.9%; Average loss: 3.5335
# Iteration: 638; Percent complete: 16.0%; Average loss: 3.4825
# Iteration: 639; Percent complete: 16.0%; Average loss: 3.7605
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.6808
# Iteration: 641; Percent complete: 16.0%; Average loss: 3.7118
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.4995
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.6597
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.4420
# Iteration: 645; Percent complete: 16.1%; Average loss: 3.7981
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.7406
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.3801
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.5993
# Iteration: 649; Percent complete: 16.2%; Average loss: 3.6069
# Iteration: 650; Percent complete: 16.2%; Average loss: 3.7737
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.5478
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.5387
# Iteration: 653; Percent complete: 16.3%; Average loss: 4.0341
# Iteration: 654; Percent complete: 16.4%; Average loss: 3.7189
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.6952
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.6488
# Iteration: 657; Percent complete: 16.4%; Average loss: 3.5224
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.5981
# Iteration: 659; Percent complete: 16.5%; Average loss: 3.3994
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.5594
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.6349
# Iteration: 662; Percent complete: 16.6%; Average loss: 3.7615
# Iteration: 663; Percent complete: 16.6%; Average loss: 3.4940
# Iteration: 664; Percent complete: 16.6%; Average loss: 3.5064
# Iteration: 665; Percent complete: 16.6%; Average loss: 3.8199
# Iteration: 666; Percent complete: 16.7%; Average loss: 3.5200
# Iteration: 667; Percent complete: 16.7%; Average loss: 3.5754
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.8491
# Iteration: 669; Percent complete: 16.7%; Average loss: 3.8134
# Iteration: 670; Percent complete: 16.8%; Average loss: 3.8517
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.3365
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.9650
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.6113
# Iteration: 674; Percent complete: 16.9%; Average loss: 3.6008
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.8552
# Iteration: 676; Percent complete: 16.9%; Average loss: 3.6610
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.5225
# Iteration: 678; Percent complete: 17.0%; Average loss: 3.3291
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.4484
# Iteration: 680; Percent complete: 17.0%; Average loss: 3.3292
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.8047
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.6605
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.4413
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.4172
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.6372
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.5188
# Iteration: 687; Percent complete: 17.2%; Average loss: 3.8313
# Iteration: 688; Percent complete: 17.2%; Average loss: 3.7938
# Iteration: 689; Percent complete: 17.2%; Average loss: 3.6902
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.7290
# Iteration: 691; Percent complete: 17.3%; Average loss: 3.4694
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.7314
# Iteration: 693; Percent complete: 17.3%; Average loss: 3.7570
# Iteration: 694; Percent complete: 17.3%; Average loss: 3.5492
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.3906
# Iteration: 696; Percent complete: 17.4%; Average loss: 3.7002
# Iteration: 697; Percent complete: 17.4%; Average loss: 3.6406
# Iteration: 698; Percent complete: 17.4%; Average loss: 3.6070
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.8020
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.7964
# Iteration: 701; Percent complete: 17.5%; Average loss: 3.5913
# Iteration: 702; Percent complete: 17.5%; Average loss: 3.4397
# Iteration: 703; Percent complete: 17.6%; Average loss: 3.6446
# Iteration: 704; Percent complete: 17.6%; Average loss: 3.5576
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.8883
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.7518
# Iteration: 707; Percent complete: 17.7%; Average loss: 3.6112
# Iteration: 708; Percent complete: 17.7%; Average loss: 3.4905
# Iteration: 709; Percent complete: 17.7%; Average loss: 3.6191
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.6135
# Iteration: 711; Percent complete: 17.8%; Average loss: 3.3818
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.7823
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.8831
# Iteration: 714; Percent complete: 17.8%; Average loss: 3.5424
# Iteration: 715; Percent complete: 17.9%; Average loss: 3.5330
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.8993
# Iteration: 717; Percent complete: 17.9%; Average loss: 3.5803
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.6705
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.5501
# Iteration: 720; Percent complete: 18.0%; Average loss: 3.3611
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.7109
# Iteration: 722; Percent complete: 18.1%; Average loss: 3.7815
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.7649
# Iteration: 724; Percent complete: 18.1%; Average loss: 3.4456
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.7083
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.3300
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.7939
# Iteration: 728; Percent complete: 18.2%; Average loss: 3.5261
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.8221
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.4613
# Iteration: 731; Percent complete: 18.3%; Average loss: 3.6037
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.4478
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.3343
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.9052
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.5971
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.6387
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.5614
# Iteration: 738; Percent complete: 18.4%; Average loss: 3.6389
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.5683
# Iteration: 740; Percent complete: 18.5%; Average loss: 3.5897
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.6539
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.7918
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.3516
# Iteration: 744; Percent complete: 18.6%; Average loss: 3.4699
# Iteration: 745; Percent complete: 18.6%; Average loss: 3.6455
# Iteration: 746; Percent complete: 18.6%; Average loss: 3.4959
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.4942
# Iteration: 748; Percent complete: 18.7%; Average loss: 3.4864
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.4456
# Iteration: 750; Percent complete: 18.8%; Average loss: 3.4069
# Iteration: 751; Percent complete: 18.8%; Average loss: 3.4431
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.6948
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.4504
# Iteration: 754; Percent complete: 18.9%; Average loss: 3.5630
# Iteration: 755; Percent complete: 18.9%; Average loss: 3.4066
# Iteration: 756; Percent complete: 18.9%; Average loss: 3.4674
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.5714
# Iteration: 758; Percent complete: 18.9%; Average loss: 3.4453
# Iteration: 759; Percent complete: 19.0%; Average loss: 3.5298
# Iteration: 760; Percent complete: 19.0%; Average loss: 3.6903
# Iteration: 761; Percent complete: 19.0%; Average loss: 3.9272
# Iteration: 762; Percent complete: 19.1%; Average loss: 3.6184
# Iteration: 763; Percent complete: 19.1%; Average loss: 3.8199
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.6501
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.4822
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.6348
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.5166
# Iteration: 768; Percent complete: 19.2%; Average loss: 3.4302
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.7391
# Iteration: 770; Percent complete: 19.2%; Average loss: 3.5689
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.6103
# Iteration: 772; Percent complete: 19.3%; Average loss: 3.5932
# Iteration: 773; Percent complete: 19.3%; Average loss: 3.5009
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.3650
# Iteration: 775; Percent complete: 19.4%; Average loss: 3.6060
# Iteration: 776; Percent complete: 19.4%; Average loss: 3.6730
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.7492
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.8655
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.3554
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.6459
# Iteration: 781; Percent complete: 19.5%; Average loss: 3.5232
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 2.8967
# Iteration: 3749; Percent complete: 93.7%; Average loss: 2.6488
# Iteration: 3750; Percent complete: 93.8%; Average loss: 2.7221
# Iteration: 3751; Percent complete: 93.8%; Average loss: 2.5551
# Iteration: 3752; Percent complete: 93.8%; Average loss: 2.5774
# Iteration: 3753; Percent complete: 93.8%; Average loss: 2.8250
# Iteration: 3754; Percent complete: 93.8%; Average loss: 2.6377
# Iteration: 3755; Percent complete: 93.9%; Average loss: 2.7204
# Iteration: 3756; Percent complete: 93.9%; Average loss: 2.4758
# Iteration: 3757; Percent complete: 93.9%; Average loss: 2.7394
# Iteration: 3758; Percent complete: 94.0%; Average loss: 2.5914
# Iteration: 3759; Percent complete: 94.0%; Average loss: 2.7156
# Iteration: 3760; Percent complete: 94.0%; Average loss: 2.5305
# Iteration: 3761; Percent complete: 94.0%; Average loss: 2.7056
# Iteration: 3762; Percent complete: 94.0%; Average loss: 2.4859
# Iteration: 3763; Percent complete: 94.1%; Average loss: 2.5464
# Iteration: 3764; Percent complete: 94.1%; Average loss: 2.7670
# Iteration: 3765; Percent complete: 94.1%; Average loss: 2.6636
# Iteration: 3766; Percent complete: 94.2%; Average loss: 2.5782
# Iteration: 3767; Percent complete: 94.2%; Average loss: 2.8510
# Iteration: 3768; Percent complete: 94.2%; Average loss: 2.5231
# Iteration: 3769; Percent complete: 94.2%; Average loss: 2.7914
# Iteration: 3770; Percent complete: 94.2%; Average loss: 2.5494
# Iteration: 3771; Percent complete: 94.3%; Average loss: 2.6223
# Iteration: 3772; Percent complete: 94.3%; Average loss: 2.4375
# Iteration: 3773; Percent complete: 94.3%; Average loss: 2.8388
# Iteration: 3774; Percent complete: 94.3%; Average loss: 2.4879
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.8287
# Iteration: 3776; Percent complete: 94.4%; Average loss: 2.4760
# Iteration: 3777; Percent complete: 94.4%; Average loss: 2.6095
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.6172
# Iteration: 3779; Percent complete: 94.5%; Average loss: 2.4435
# Iteration: 3780; Percent complete: 94.5%; Average loss: 2.5985
# Iteration: 3781; Percent complete: 94.5%; Average loss: 2.7358
# Iteration: 3782; Percent complete: 94.5%; Average loss: 2.6434
# Iteration: 3783; Percent complete: 94.6%; Average loss: 2.7235
# Iteration: 3784; Percent complete: 94.6%; Average loss: 2.7000
# Iteration: 3785; Percent complete: 94.6%; Average loss: 2.6360
# Iteration: 3786; Percent complete: 94.7%; Average loss: 2.6799
# Iteration: 3787; Percent complete: 94.7%; Average loss: 2.6234
# Iteration: 3788; Percent complete: 94.7%; Average loss: 2.6032
# Iteration: 3789; Percent complete: 94.7%; Average loss: 2.8647
# Iteration: 3790; Percent complete: 94.8%; Average loss: 2.7059
# Iteration: 3791; Percent complete: 94.8%; Average loss: 2.5237
# Iteration: 3792; Percent complete: 94.8%; Average loss: 2.5820
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.8189
# Iteration: 3794; Percent complete: 94.8%; Average loss: 2.5117
# Iteration: 3795; Percent complete: 94.9%; Average loss: 2.7966
# Iteration: 3796; Percent complete: 94.9%; Average loss: 2.8504
# Iteration: 3797; Percent complete: 94.9%; Average loss: 2.5333
# Iteration: 3798; Percent complete: 95.0%; Average loss: 2.5596
# Iteration: 3799; Percent complete: 95.0%; Average loss: 2.7307
# Iteration: 3800; Percent complete: 95.0%; Average loss: 2.4090
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.5657
# Iteration: 3802; Percent complete: 95.0%; Average loss: 2.6515
# Iteration: 3803; Percent complete: 95.1%; Average loss: 2.5463
# Iteration: 3804; Percent complete: 95.1%; Average loss: 2.5968
# Iteration: 3805; Percent complete: 95.1%; Average loss: 2.7647
# Iteration: 3806; Percent complete: 95.2%; Average loss: 2.5514
# Iteration: 3807; Percent complete: 95.2%; Average loss: 2.4619
# Iteration: 3808; Percent complete: 95.2%; Average loss: 2.7798
# Iteration: 3809; Percent complete: 95.2%; Average loss: 2.6710
# Iteration: 3810; Percent complete: 95.2%; Average loss: 2.5009
# Iteration: 3811; Percent complete: 95.3%; Average loss: 2.5734
# Iteration: 3812; Percent complete: 95.3%; Average loss: 2.7409
# Iteration: 3813; Percent complete: 95.3%; Average loss: 2.7178
# Iteration: 3814; Percent complete: 95.3%; Average loss: 2.6398
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.6319
# Iteration: 3816; Percent complete: 95.4%; Average loss: 2.6324
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.7095
# Iteration: 3818; Percent complete: 95.5%; Average loss: 2.6272
# Iteration: 3819; Percent complete: 95.5%; Average loss: 2.4830
# Iteration: 3820; Percent complete: 95.5%; Average loss: 2.5772
# Iteration: 3821; Percent complete: 95.5%; Average loss: 2.6651
# Iteration: 3822; Percent complete: 95.5%; Average loss: 2.6853
# Iteration: 3823; Percent complete: 95.6%; Average loss: 2.4433
# Iteration: 3824; Percent complete: 95.6%; Average loss: 2.6204
# Iteration: 3825; Percent complete: 95.6%; Average loss: 2.5106
# Iteration: 3826; Percent complete: 95.7%; Average loss: 2.6742
# Iteration: 3827; Percent complete: 95.7%; Average loss: 2.6317
# Iteration: 3828; Percent complete: 95.7%; Average loss: 2.6868
# Iteration: 3829; Percent complete: 95.7%; Average loss: 2.7751
# Iteration: 3830; Percent complete: 95.8%; Average loss: 2.6351
# Iteration: 3831; Percent complete: 95.8%; Average loss: 2.7839
# Iteration: 3832; Percent complete: 95.8%; Average loss: 2.7223
# Iteration: 3833; Percent complete: 95.8%; Average loss: 2.7382
# Iteration: 3834; Percent complete: 95.9%; Average loss: 2.6598
# Iteration: 3835; Percent complete: 95.9%; Average loss: 2.6907
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.5325
# Iteration: 3837; Percent complete: 95.9%; Average loss: 2.5957
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.7534
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.7256
# Iteration: 3840; Percent complete: 96.0%; Average loss: 2.5792
# Iteration: 3841; Percent complete: 96.0%; Average loss: 2.4657
# Iteration: 3842; Percent complete: 96.0%; Average loss: 2.7324
# Iteration: 3843; Percent complete: 96.1%; Average loss: 2.4951
# Iteration: 3844; Percent complete: 96.1%; Average loss: 2.5821
# Iteration: 3845; Percent complete: 96.1%; Average loss: 2.6381
# Iteration: 3846; Percent complete: 96.2%; Average loss: 2.7669
# Iteration: 3847; Percent complete: 96.2%; Average loss: 2.6310
# Iteration: 3848; Percent complete: 96.2%; Average loss: 3.0281
# Iteration: 3849; Percent complete: 96.2%; Average loss: 2.6912
# Iteration: 3850; Percent complete: 96.2%; Average loss: 2.4757
# Iteration: 3851; Percent complete: 96.3%; Average loss: 2.6469
# Iteration: 3852; Percent complete: 96.3%; Average loss: 2.5754
# Iteration: 3853; Percent complete: 96.3%; Average loss: 2.6478
# Iteration: 3854; Percent complete: 96.4%; Average loss: 2.8956
# Iteration: 3855; Percent complete: 96.4%; Average loss: 2.6707
# Iteration: 3856; Percent complete: 96.4%; Average loss: 2.3471
# Iteration: 3857; Percent complete: 96.4%; Average loss: 2.4518
# Iteration: 3858; Percent complete: 96.5%; Average loss: 2.8209
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.6817
# Iteration: 3860; Percent complete: 96.5%; Average loss: 2.5760
# Iteration: 3861; Percent complete: 96.5%; Average loss: 2.6348
# Iteration: 3862; Percent complete: 96.5%; Average loss: 2.5659
# Iteration: 3863; Percent complete: 96.6%; Average loss: 2.7181
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.9646
# Iteration: 3865; Percent complete: 96.6%; Average loss: 2.5591
# Iteration: 3866; Percent complete: 96.7%; Average loss: 2.4308
# Iteration: 3867; Percent complete: 96.7%; Average loss: 2.6946
# Iteration: 3868; Percent complete: 96.7%; Average loss: 2.7240
# Iteration: 3869; Percent complete: 96.7%; Average loss: 2.8530
# Iteration: 3870; Percent complete: 96.8%; Average loss: 2.2567
# Iteration: 3871; Percent complete: 96.8%; Average loss: 2.5647
# Iteration: 3872; Percent complete: 96.8%; Average loss: 2.9013
# Iteration: 3873; Percent complete: 96.8%; Average loss: 2.9583
# Iteration: 3874; Percent complete: 96.9%; Average loss: 2.5103
# Iteration: 3875; Percent complete: 96.9%; Average loss: 2.6209
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.5901
# Iteration: 3877; Percent complete: 96.9%; Average loss: 2.6727
# Iteration: 3878; Percent complete: 97.0%; Average loss: 2.8414
# Iteration: 3879; Percent complete: 97.0%; Average loss: 2.6690
# Iteration: 3880; Percent complete: 97.0%; Average loss: 2.5656
# Iteration: 3881; Percent complete: 97.0%; Average loss: 2.4687
# Iteration: 3882; Percent complete: 97.0%; Average loss: 2.5871
# Iteration: 3883; Percent complete: 97.1%; Average loss: 2.5330
# Iteration: 3884; Percent complete: 97.1%; Average loss: 2.5286
# Iteration: 3885; Percent complete: 97.1%; Average loss: 2.8058
# Iteration: 3886; Percent complete: 97.2%; Average loss: 2.5032
# Iteration: 3887; Percent complete: 97.2%; Average loss: 2.5256
# Iteration: 3888; Percent complete: 97.2%; Average loss: 2.4056
# Iteration: 3889; Percent complete: 97.2%; Average loss: 2.6677
# Iteration: 3890; Percent complete: 97.2%; Average loss: 2.6291
# Iteration: 3891; Percent complete: 97.3%; Average loss: 2.6548
# Iteration: 3892; Percent complete: 97.3%; Average loss: 2.4734
# Iteration: 3893; Percent complete: 97.3%; Average loss: 2.5585
# Iteration: 3894; Percent complete: 97.4%; Average loss: 2.4035
# Iteration: 3895; Percent complete: 97.4%; Average loss: 2.9025
# Iteration: 3896; Percent complete: 97.4%; Average loss: 2.8932
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.5473
# Iteration: 3898; Percent complete: 97.5%; Average loss: 2.7247
# Iteration: 3899; Percent complete: 97.5%; Average loss: 2.5047
# Iteration: 3900; Percent complete: 97.5%; Average loss: 2.7399
# Iteration: 3901; Percent complete: 97.5%; Average loss: 2.5421
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.6178
# Iteration: 3903; Percent complete: 97.6%; Average loss: 2.7055
# Iteration: 3904; Percent complete: 97.6%; Average loss: 2.7278
# Iteration: 3905; Percent complete: 97.6%; Average loss: 2.8026
# Iteration: 3906; Percent complete: 97.7%; Average loss: 2.7652
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.6016
# Iteration: 3908; Percent complete: 97.7%; Average loss: 2.8136
# Iteration: 3909; Percent complete: 97.7%; Average loss: 2.4768
# Iteration: 3910; Percent complete: 97.8%; Average loss: 2.3814
# Iteration: 3911; Percent complete: 97.8%; Average loss: 2.5470
# Iteration: 3912; Percent complete: 97.8%; Average loss: 2.4337
# Iteration: 3913; Percent complete: 97.8%; Average loss: 2.5699
# Iteration: 3914; Percent complete: 97.9%; Average loss: 2.8938
# Iteration: 3915; Percent complete: 97.9%; Average loss: 2.7120
# Iteration: 3916; Percent complete: 97.9%; Average loss: 2.5420
# Iteration: 3917; Percent complete: 97.9%; Average loss: 2.7250
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.8290
# Iteration: 3919; Percent complete: 98.0%; Average loss: 2.8374
# Iteration: 3920; Percent complete: 98.0%; Average loss: 2.6072
# Iteration: 3921; Percent complete: 98.0%; Average loss: 2.6805
# Iteration: 3922; Percent complete: 98.0%; Average loss: 2.7226
# Iteration: 3923; Percent complete: 98.1%; Average loss: 2.6272
# Iteration: 3924; Percent complete: 98.1%; Average loss: 2.3261
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.7117
# Iteration: 3926; Percent complete: 98.2%; Average loss: 2.4231
# Iteration: 3927; Percent complete: 98.2%; Average loss: 2.6853
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.6256
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.5329
# Iteration: 3930; Percent complete: 98.2%; Average loss: 2.6495
# Iteration: 3931; Percent complete: 98.3%; Average loss: 2.5910
# Iteration: 3932; Percent complete: 98.3%; Average loss: 2.5608
# Iteration: 3933; Percent complete: 98.3%; Average loss: 2.6524
# Iteration: 3934; Percent complete: 98.4%; Average loss: 2.7424
# Iteration: 3935; Percent complete: 98.4%; Average loss: 2.6063
# Iteration: 3936; Percent complete: 98.4%; Average loss: 2.8755
# Iteration: 3937; Percent complete: 98.4%; Average loss: 2.6186
# Iteration: 3938; Percent complete: 98.5%; Average loss: 2.4371
# Iteration: 3939; Percent complete: 98.5%; Average loss: 2.6040
# Iteration: 3940; Percent complete: 98.5%; Average loss: 2.6480
# Iteration: 3941; Percent complete: 98.5%; Average loss: 2.4492
# Iteration: 3942; Percent complete: 98.6%; Average loss: 2.3553
# Iteration: 3943; Percent complete: 98.6%; Average loss: 2.6879
# Iteration: 3944; Percent complete: 98.6%; Average loss: 2.5401
# Iteration: 3945; Percent complete: 98.6%; Average loss: 2.5118
# Iteration: 3946; Percent complete: 98.7%; Average loss: 2.5207
# Iteration: 3947; Percent complete: 98.7%; Average loss: 2.6163
# Iteration: 3948; Percent complete: 98.7%; Average loss: 2.6347
# Iteration: 3949; Percent complete: 98.7%; Average loss: 2.7238
# Iteration: 3950; Percent complete: 98.8%; Average loss: 2.4608
# Iteration: 3951; Percent complete: 98.8%; Average loss: 2.9404
# Iteration: 3952; Percent complete: 98.8%; Average loss: 2.5212
# Iteration: 3953; Percent complete: 98.8%; Average loss: 2.4941
# Iteration: 3954; Percent complete: 98.9%; Average loss: 2.7750
# Iteration: 3955; Percent complete: 98.9%; Average loss: 2.6467
# Iteration: 3956; Percent complete: 98.9%; Average loss: 2.7030
# Iteration: 3957; Percent complete: 98.9%; Average loss: 2.7306
# Iteration: 3958; Percent complete: 99.0%; Average loss: 2.6447
# Iteration: 3959; Percent complete: 99.0%; Average loss: 2.5619
# Iteration: 3960; Percent complete: 99.0%; Average loss: 2.4226
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.6914
# Iteration: 3962; Percent complete: 99.1%; Average loss: 2.6942
# Iteration: 3963; Percent complete: 99.1%; Average loss: 2.4425
# Iteration: 3964; Percent complete: 99.1%; Average loss: 2.7136
# Iteration: 3965; Percent complete: 99.1%; Average loss: 2.5910
# Iteration: 3966; Percent complete: 99.2%; Average loss: 2.8065
# Iteration: 3967; Percent complete: 99.2%; Average loss: 2.6076
# Iteration: 3968; Percent complete: 99.2%; Average loss: 2.4589
# Iteration: 3969; Percent complete: 99.2%; Average loss: 2.8180
# Iteration: 3970; Percent complete: 99.2%; Average loss: 2.7279
# Iteration: 3971; Percent complete: 99.3%; Average loss: 2.5563
# Iteration: 3972; Percent complete: 99.3%; Average loss: 2.3347
# Iteration: 3973; Percent complete: 99.3%; Average loss: 2.5917
# Iteration: 3974; Percent complete: 99.4%; Average loss: 2.5866
# Iteration: 3975; Percent complete: 99.4%; Average loss: 2.5697
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.8004
# Iteration: 3977; Percent complete: 99.4%; Average loss: 2.6688
# Iteration: 3978; Percent complete: 99.5%; Average loss: 2.4083
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.6600
# Iteration: 3980; Percent complete: 99.5%; Average loss: 2.5043
# Iteration: 3981; Percent complete: 99.5%; Average loss: 2.5170
# Iteration: 3982; Percent complete: 99.6%; Average loss: 2.7112
# Iteration: 3983; Percent complete: 99.6%; Average loss: 2.5336
# Iteration: 3984; Percent complete: 99.6%; Average loss: 2.6380
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.4945
# Iteration: 3986; Percent complete: 99.7%; Average loss: 2.5919
# Iteration: 3987; Percent complete: 99.7%; Average loss: 2.5652
# Iteration: 3988; Percent complete: 99.7%; Average loss: 2.6603
# Iteration: 3989; Percent complete: 99.7%; Average loss: 2.9276
# Iteration: 3990; Percent complete: 99.8%; Average loss: 2.8145
# Iteration: 3991; Percent complete: 99.8%; Average loss: 2.5996
# Iteration: 3992; Percent complete: 99.8%; Average loss: 2.6230
# Iteration: 3993; Percent complete: 99.8%; Average loss: 2.7806
# Iteration: 3994; Percent complete: 99.9%; Average loss: 2.5228
# Iteration: 3995; Percent complete: 99.9%; Average loss: 2.5055
# Iteration: 3996; Percent complete: 99.9%; Average loss: 2.8415
# Iteration: 3997; Percent complete: 99.9%; Average loss: 2.6283
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.6097
# Iteration: 3999; Percent complete: 100.0%; Average loss: 2.3089
# Iteration: 4000; Percent complete: 100.0%; Average loss: 2.3445

# %% [markdown]
# Run Evaluation
# ==============
#
# To chat with your model, run the following block.

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# Begin chatting (uncomment and run the following line to begin)
# evaluateInput(encoder, decoder, searcher, voc)

# %%
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > who are you?
# Bot: i m here . s . .
# > what
# Bot: i m sorry . s gone . .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-4e20b9561b77> in <cell line: 0>()
# ----> 1 evaluateInput(encoder, decoder, searcher, voc)
#
# <ipython-input-20-7cdfa7345e53> in evaluateInput(encoder, decoder, searcher, voc)
#      22         try:
#      23             # Get input sentence
# ---> 24             input_sentence = input('> ')
#      25             # Check if it is quit case
#      26             if input_sentence == 'q' or input_sentence == 'quit': break
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# Conclusion
# ==========
#
# That's all for this one, folks. Congratulations, you now know the
# fundamentals to building a generative chatbot model! If you're
# interested, you can try tailoring the chatbot's behavior by tweaking the
# model and training parameters and customizing the data that you train
# the model on.
#
# Check out the other tutorials for more cool deep learning applications
# in PyTorch!
